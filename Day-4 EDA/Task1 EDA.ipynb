# %% [markdown]
# # Employee Salary Analysis & Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('employee_data.csv')
print(df)
# Out:
#     id                name  age                department  salary  experience
# 0    4      Elden Strachan   78                   Support      22          52
# 1   42       Angus Moloney   83                 Marketing      61          39
# 2   87     Morgan Stienham   95                  Services       3          79
# 3   30       Alyce Robarts   39                     Legal      13          78
# 4   80    Enriqueta Drover   20                Accounting      43           7
# ..  ..                 ...  ...                       ...     ...         ...
# 95  94        Hunt Docksey   22  Research and Development      75          88
# 96  68     Lorenzo Perrott   27                     Sales      87          41
# 97  62  Elizabet MacTavish    2  Research and Development       7          44
# 98  55      Laney Nelthorp   66                Accounting      25          38
# 99  34  Prescott Wooddisse   16                     Sales      16          27
#
# [100 rows x 6 columns]

# %%
df
# Out:
#     id                name  age                department  salary  experience
# 0    4      Elden Strachan   78                   Support      22          52
# 1   42       Angus Moloney   83                 Marketing      61          39
# 2   87     Morgan Stienham   95                  Services       3          79
# 3   30       Alyce Robarts   39                     Legal      13          78
# 4   80    Enriqueta Drover   20                Accounting      43           7
# ..  ..                 ...  ...                       ...     ...         ...
# 95  94        Hunt Docksey   22  Research and Development      75          88
# 96  68     Lorenzo Perrott   27                     Sales      87          41
# 97  62  Elizabet MacTavish    2  Research and Development       7          44
# 98  55      Laney Nelthorp   66                Accounting      25          38
# 99  34  Prescott Wooddisse   16                     Sales      16          27
#
# [100 rows x 6 columns]

# %%
# 2. Find the average salary in each department
average_salary = df.groupby('department')['salary'].mean()
print("Average Salary in Each Department:")
print(average_salary)
print("\n")
# Out:
# Average Salary in Each Department:
# department
# Accounting                  54.000000
# Business Development        45.090909
# Engineering                 69.555556
# Human Resources             38.285714
# Legal                       40.555556
# Marketing                   53.000000
# Product Management          63.400000
# Research and Development    47.800000
# Sales                       58.000000
# Services                    18.000000
# Support                     57.750000
# Training                    63.000000
# Name: salary, dtype: float64

# %%
# 3. Find the highest and lowest salary in the company
highest_salary = df['salary'].max()
lowest_salary = df['salary'].min()
print(f"Highest Salary in the Company: {highest_salary}")
print(f"Lowest Salary in the Company: {lowest_salary}")
# Out:
# Highest Salary in the Company: 100
# Lowest Salary in the Company: 2

# %%
# 4. Find the employee with the maximum salary
employee_max_salary = df[df['salary'] == highest_salary]
print("Employee with the Maximum Salary:")
print(employee_max_salary)
# Out:
# Employee with the Maximum Salary:
#     id              name  age          department  salary  experience
# 39  11  Kristi Coleyshaw   90  Product Management     100          73
# 50  66     Judas Howroyd   50  Product Management     100          75

# %%
# 5. Count the number of employees in each department
employee_count = df['department'].value_counts()
print("Number of Employees in Each Department:")
print(employee_count)
# Out:
# Number of Employees in Each Department:
# department
# Accounting                  15
# Sales                       11
# Business Development        11
# Research and Development    10
# Engineering                  9
# Legal                        9
# Support                      8
# Marketing                    8
# Human Resources              7
# Training                     5
# Product Management           5
# Services                     2
# Name: count, dtype: int64

# %%
# 6. Plot a bar chart showing the number of employees in each department
plt.figure(figsize=(10, 6))
employee_count.plot(kind='bar', color='skyblue')
plt.title('Number of Employees in Each Department')
plt.xlabel('Department')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Save the plot as a PNG file
plt.savefig('employee_count_by_department.png')

# Display the plot
plt.show()

# %%
# 7. Plot a pie chart showing salary distribution by department
plt.figure(figsize=(8, 8))
df.groupby('department')['salary'].sum().plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Salary Distribution by Department')
plt.ylabel('')

# Save the plot as a PNG file
plt.savefig('salary_distribution_by_department.png')

# Display the plot
plt.show()

# %%
# 8. Scatter plot showing salary vs experience
# Assuming 'experience' column exists in the dataset
if 'experience' in df.columns:
    plt.figure(figsize=(10, 6))
    plt.scatter(df['experience'], df['salary'], color='skyblue')
    plt.title('Salary vs Experience')
    plt.xlabel('Experience (Years)')
    plt.ylabel('Salary')
    plt.grid(True)

    # Save the plot as a PNG file
    plt.savefig('salary_vs_experience.png')

    # Display the plot
    plt.show()
else:
    print("The 'experience' column is not present in the dataset.")

# %%
# 9. Find employees who earn more than the average salary
average_salary_value = df['salary'].mean()
employees_above_average_salary = df[df['salary'] > average_salary_value]
print("Employees Who Earn More Than the Average Salary:")
print(employees_above_average_salary)
# Out:
# Employees Who Earn More Than the Average Salary:
#     id                  name  age                department  salary  \
# 1   42         Angus Moloney   83                 Marketing      61
# 5   63           Trudi Ridde   17                     Sales      75
# 6   28       Justis Larmouth   20      Business Development      60
# 7   67         Ruperta Laise   63      Business Development      90
# 8   95           Dennet Jina   14                Accounting      79
# 10   2       Marylou Buessen   61                Accounting      66
# 12  61  Raynard Ravenscroftt   47                     Legal      65
# 13  19          Lulita Orgee   21                   Support      77
# 14  96           Perkin Yare   39               Engineering      90
# 15  49         Ulrich Ilchuk   56                 Marketing      63
# 16  22        Edik Hedingham   62                Accounting      91
# 17  15        Saleem Fernier   18                  Training      94
# ...

# %%
# 10. Sort employees based on salary in descending order
sorted_employees = df.sort_values(by='salary', ascending=False)
print("Employees Sorted Based on Salary in Descending Order:")
print(sorted_employees)
# Out:
# Employees Sorted Based on Salary in Descending Order:
#      id               name  age            department  salary  experience
# 50   66      Judas Howroyd   50    Product Management     100          75
# 39   11   Kristi Coleyshaw   90    Product Management     100          73
# 75   56     Diandra Ewdale   32              Training      99          47
# 37    5    Phillida Meijer   83           Engineering      99          29
# 67   95      Patric Frosch   76            Accounting      97          48
# ..  ...                ...  ...                   ...     ...         ...
# 26  100  Margarita Slocomb   23            Accounting       6          67
# 33   11      Damien Dudley   24                 Sales       3          35
# 2    87    Morgan Stienham   95              Services       3          79
# 55   59          Tove Pech   36            Accounting       2          95
# 51   13         Cosmo Grew   55  Business Development       2          39
#
# [100 rows x 6 columns]
